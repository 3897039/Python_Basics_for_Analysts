# %% [markdown]
# ## Задача 2

# %% [markdown]
# ### 2.1. Изучите распределение домов от наличия вида на набережную
# - Постройте график
# - Сделайте выводы

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('./kc_house_data.csv', encoding='1251', sep=',')
df.head(5)
data = df['waterfront'].value_counts().reset_index()
data.head()
# Out:
#    waterfront  count
# 0           0  21450
# 1           1    163

# %%
plt.figure(figsize=(8, 6))

plt.bar(data['waterfront'], data['count'])

plt.title('Вид на набережную')
plt.xlabel('Присутствие вида')
plt.ylabel('кол-во домов')
plt.grid();

# %% [markdown]
# ### 2.2. Изучите распределение этажей домов

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('./kc_house_data.csv', encoding='1251', sep=',')
df.head(5)
data = df['floors'].value_counts()
data
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))

plt.pie(data, labels=data.index, autopct='%1.2f%%')
plt.title('Распределение этажности домов');

# больше всего домов одноэтажных, меньше всего - в 3,5 этажа

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('./kc_house_data.csv', encoding='1251', sep=',')
df.head(5)
data = df['condition'].value_counts()
data
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))

plt.pie(data, labels=data.index, autopct='%1.2f%%')
plt.title('Состояние домов');

# в основном состояние домов среднее, в отличном состоянии находится всего лишь около 8% домов
