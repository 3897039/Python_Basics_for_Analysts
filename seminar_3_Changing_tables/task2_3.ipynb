# %% [markdown]
# ## Задача 2
# - Создайте датафрейм с клиентами
# - 2.1 Присоедините к таблице clients данные по домам через метод join
# - 2.2 Присоедините к таблице clients данные по домам через метод merge
# Это нужно, чтобы понимать, какие дома покупались клиентами
# house_id - это индексы датафрейма с домами

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./kc_house_data.csv', encoding='1251', sep=',')
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
clients = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]
})
clients.head(5)
# Out:
#    client_id    house_id
# 0       1459  8965450190
# 1       4684  6823100225
# 2       3498  5104540330
# 3       3942  2131701075
# 4       4535  1522700060

# %% [markdown]
# ## 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
houses_id = clients.set_index('house_id') 
houses_id.head()
# Out:
#             client_id
# house_id
# 8965450190       1459
# 6823100225       4684
# 5104540330       3498
# 2131701075       3942
# 1522700060       4535

# %%
df.rename(columns = {'id': 'house_id'}, inplace=True)
df.head(5)
# Out:
#      house_id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df_id = df.set_index('house_id')
df_id.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# house_id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# house_id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df_id.join(houses_id).head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# house_id
# 1000102   20140916T000000  280000.0         6       3.00         2400
# 1000102   20150422T000000  300000.0         6       3.00         2400
# 1200019   20140508T000000  647500.0         4       1.75         2060
# 1200021   20140811T000000  400000.0         3       1.00         1460
# 2800031   20150401T000000  235000.0         3       1.00         1430
#
#           sqft_lot  floors  waterfront  view  condition  ...  sqft_above  \
# house_id                                                 ...
# 1000102       9373     2.0           0     0          3  ...        2400
# 1000102       9373     2.0           0     0          3  ...        2400
# 1200019      26036     1.0           0     0          4  ...        1160
# 1200021      43000     1.0           0     0          3  ...        1460
# 2800031       7599     1.5           0     0          4  ...        1010
#
# ...

# %% [markdown]
# ## 2.2 Присоедините к таблице clients данные по домам через метод merge

# %%
merged = clients.merge(df, left_on='house_id', right_on='house_id')
merged.head()
# Out:
#    client_id    house_id             date     price  bedrooms  bathrooms  \
# 0       1459  8965450190  20150218T000000  295000.0         3       2.50
# 1       4684  6823100225  20150414T000000  700000.0         4       1.75
# 2       3498  5104540330  20150508T000000  679000.0         4       2.50
# 3       3942  2131701075  20141204T000000  420000.0         3       1.75
# 4       4535  1522700060  20140624T000000  518000.0         4       2.75
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1500      3060     2.0           0  ...      7        1500
# 1         1870      6000     1.0           0  ...      8        1670
# 2         3680      7236     2.0           0  ...     10        3680
# 3         1720      5000     1.5           0  ...      8        1720
# 4         2520     14021     2.0           0  ...      9        2520
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...
